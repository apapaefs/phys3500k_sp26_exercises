# %%
import numpy as np
import random 
n=4 # number of dimensions
N=5 # number of integration points 
for i in range(int(N)):
    x = np.zeros(n)
    for i in range(n): 
        x[i] = random.random()
    # here pass the vector to your func as func(x)
    print('Nth integration numpy vector=', x)

# how to sum up the squares:
# example on the last value of x generated above:
sumxsq = np.sum(np.square(x))
print(sumxsq, 'vs manual=', x[0]**2 + x[1]**2 + x[2]**2 + x[3]**2)
# then do 1 - sumxsq to get the theta function argument
# Out:
# Nth integration numpy vector= [0.80043633 0.78567995 0.59240665 0.39435957]
# Nth integration numpy vector= [0.55679392 0.68029267 0.06109188 0.81816213]
# Nth integration numpy vector= [0.38943832 0.95270736 0.7041247  0.21115919]
# Nth integration numpy vector= [0.44778193 0.29976035 0.30471681 0.52295599]
# Nth integration numpy vector= [0.42542061 0.59371747 0.67267032 0.68487151]
# 1.455017473034816 vs manual= 1.455017473034816
