# %%
from sympy import *

# define the symbols
# simple example
# define the symbols
y, z = symbols('y z')
# define the functions
G = symbols('G', cls=Function)
G = G(y, z)
G = y**2 + y**3 * z
# take the derivative
diff(G, y, 1)

# Exercise 9.1:
# define the symbols
r, k2 = symbols('r k^2')

# define the functions
Phi, phi = symbols(r'\Phi \phi', cls=Function)
phi = phi(r)
Phi = r**(-1/2) * phi

Eqn = diff(Phi, r, 2) + (1/r) * diff(Phi, r, 1) + k2 * Phi
pprint(latex(simplify(Eqn*r**(1/2))))
# Out:
# 1.0 k^{2} \phi{\left(r \right)} + \frac{0.25 \phi{\left(r \right)}}{r^{2.0}} + ↪
#
# ↪  1.0 \frac{d^{2}}{d r^{2}} \phi{\left(r \right)}

# %% [markdown]
# $1.0 k^{2} \phi{\left(r \right)} + \frac{0.25 \phi{\left(r \right)}}{r^{2.0}} + 1.0 \frac{d^{2}}{d r^{2}} \phi{\left(r \right)} = 0$
#
# or:
#
# $\frac{ \mathrm{d}^2 \phi } { \mathrm{d} r^2 } = - (k^2 + \frac{1}{4} r^{-2}) \phi$,
#
# of the form we need with:
#
# $K^2(r) = k^2 + 1/(4r^2)$
#
# and then:
#
# $\frac{ \mathrm{d}^2 \phi } { \mathrm{d} r^2 } = - K^2 (r) \phi$,
